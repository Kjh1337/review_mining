# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("/content/drive/MyDrive/리뷰마이닝/data.pickle","rb") as fr:
    data = pickle.load(fr)

# %%
stopwords = ['약간' , '최근' , '딸' , '밍' , '부' , '때' , '후' , '달' , '친언니' , '전' , '부탁' , '아들' , '나중' , '덕분' , '위' , 
        '대신' , '조카' , '상의' , '남편' , '플로' , '면' , '여기저기' , '오늘' , '하이' , '플' , '점' , '큐' , '감' , '이곳저곳' ,
        '돌' , '몰' , '앞' , '비람' , '씽' , '훈기' , '행' , '이후' , '기' , '셔' , '두말' , '입' , '애' , '남' , '거사' , '이해' , '전달' ,
        '팬' , '기' , '다음' , '날' , '배' , '면' , '플' '뒤' , '마왕' , '가요' , '신념' , '속' ,  '롯' , '이번' , '기회' , '신' , '차' ,
         '선짝' ,  '안' , '눈' , '월' , '원' , '밑' , '동생', '제주도' , '정도' , '옆' , '곳' , '예' , '딜' , '히' , '도' , '기와' ,
          '막' , '댁' , '사' '오른쪽' , '왼쪽' , '상도' , '요번' , '티브이' ,  '그간' , '키' , '철' , '라모', '에어로타워컨', '청', '에어로타워', '에어', '타워']

# %%
for i in range(len(data)):
    for j in stopwords:
      while j in data[i]:
            data[i].remove(j)

# %%
my_list = data
 
## Save pickle
with open("cleaned_data.pickle","wb") as fw:
    pickle.dump(my_list, fw)
